# %% [markdown]
# <a href="https://colab.research.google.com/github/ccindiu/Pemerograman-Dasar/blob/main/Tugas01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Cindy Agatha Purba"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Cindy Agatha Purba
# 20
# RPE
# 3
# Pemerograman Dasar
# False
