# %% [markdown]
# <a href="https://colab.research.google.com/github/ccindiu/Pemerograman-Dasar/blob/main/pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# jawaban latihan 1
# data sebuah panel surya
tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"
print(tegangan, arus, jenis_sel)

# jawaban latihan 2
hambatan = 0.5
arus = 5
label = "resistor"
ohm = True

print(type(hambatan))
print(type(arus))
print(type(label))
print(type(ohm))

# jawaban latihan 3
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(type("nama_unit"))
print(type("jumlah_unit"))
print(type("tegangan_keluaran"))
print(type("sedang_beroperasi"))

# jawaban latihan 4
# pembacaan pertama dan terakhir memakai indeks
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print(tegangan_harian[0], tegangan_harian[5])

# tambahkan satu pembacaan baru 220.0 dengan append()
tegangan_harian.append(220.0)
print(tegangan_harian)

# cetak jumlah total data dengan len()
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print(len(tegangan_harian))

# jawaban latihan 5
generator = {
    "nama": "motor_listrik",
    "daya_kW": 100,
    "tegangan_V": 11,
    "rpm" : 1450
}
print("nama:")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4261/2476562180.py in <cell line: 0>()
#       4 arus = 6
#       5 jenis_sel = "Monocrystalline"
# ----> 6 print(tegangan, arus, jenis_sel)
#       7
#       8 #jawaban latihan 2
#
# TypeError: 'list' object is not callable
