# %% [markdown]
# <a href="https://colab.research.google.com/github/ccindiu/Pemerograman-Dasar/blob/main/Esai_Week03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. mengapa ekspresi 10 + 5 * 2 menghasilkan 20, bukan 30
menurut sumber yang sudah saya baca, simbol + dan * merupakan operator dalam aritmatika, hasilnya bisa menjadi 20 yaitu karena dalam matematika
perkalian dan pembagian harus lebih dulu dikerjakan sebelum pejumlahan atau pengurangan,
dalam operasi arimatika python juga sama berlaku seperti itu, hasil kode yang keluar = 20
karena operasi yang dikerjakan yaitu 10 + (5 * 2) maka hasilnya adalah 20 bukan 30.

sumber:
https://www.duniailkom.com/tutorial-belajar-python-jenis-jenis-operator-aritmatika-python/
https://www.petanikode.com/python-operator/

2. Jelaskan perbedaan mendasar antara operator relasional (>, <, ==, dll.) dan operator logika (and, or, not) dalam Python.
operator relasional itu digunakan untuk membandingkan dua buah nilai, sedangkan operator logika digunakan untuk membuat operasi logika
contoh:
# Input data pengguna
warna_kesukaan = "pink"
tingkat_kecerahan = 87  # Persentase (0 - 100)
# Gabungkan operator relasional dan logika
aktifkan_efek = (warna_kesukaan == "pink") and (tingkat_kecerahan > 80)
print(aktifkan_efek)
# Output: True

3. Cari satu contoh kasus nyata (artikel, forum programmer, atau dokumentasi) tentang bug atau kesalahan perhitungan yang terjadi akibat salah memahami operator precedence
(misalnya lupa memberi tanda kurung). Ringkas kasus tersebut dalam 3–5 kalimat, lalu jelaskan bagaimana seharusnya kode itu diperbaiki.

Menurut pedoman CERT C Coding Standard (EXP00-C), programmer C sering salah menulis ekspresi seperti x & 1 == 0 untuk menguji apakah bit terakhir dari x bernilai 0.
Karena == memiliki precedence lebih tinggi daripada &, kode tersebut sebenarnya dieksekusi sebagai x & (1 == 0), yaitu x & 0, yang hasilnya selalu 0 apa pun nilai x.
Akibatnya, logika pengecekan bit tersebut gagal total dan selalu memberi hasil salah.

Perbaikan: Tambahkan tanda kurung eksplisit menjadi (x & 1) == 0, sehingga operasi AND dieksekusi dulu untuk mengambil bit terakhir, baru dibandingkan dengan 0.
Kaidah umumnya: selalu beri tanda kurung eksplisit saat mencampur operator bitwise dan perbandingan dalam satu ekspresi.

# %%
# Input data pengguna
warna_kesukaan = "pink"
tingkat_kecerahan = 87

# Gabungkan operator relasional dan logika
aktifkan_efek = (warna_kesukaan == "pink") and (tingkat_kecerahan > 80)

print(aktifkan_efek)
# Out:
# True
