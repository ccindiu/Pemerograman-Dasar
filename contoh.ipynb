# %% [markdown]
# <a href="https://colab.research.google.com/github/ccindiu/Pemerograman-Dasar/blob/main/contoh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 1
x = 2
x = 10

x = "cindy"

b = 7.6

c = True

d = False

#list
mahasiswa = ["Cindy", 4232501026, 155.1, False]
#print(mahasiswa)

print ("Nama : ",mahasiswa[0])
print ("NIM : ",mahasiswa[1])

"""
# cara satu per satu
print (x)
print(type(x))
print(type(b))
print(type(c))
print(type(d))

# cara digabung
print(type(x)),(type(b)),(type(c)),(type(d))

"""

#tuple

Mobil = ()
# Out:
# Nama :  Cindy
# NIM :  4232501026
# '\n# cara satu per satu\nprint (x)\nprint(type(x))\nprint(type(b))\nprint(type(c))\nprint(type(d))\n\n# cara digabung\nprint(type(x)),(type(b)),(type(c)),(type(d))\n\n'
